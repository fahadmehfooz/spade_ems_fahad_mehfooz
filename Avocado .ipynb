# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("avocado.csv")
df.head(60)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume       4046       4225  \
# 0            0  2015-12-27          1.33      64236.62    1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98     674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22     794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15    1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60     941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78    1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76    1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33     703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42    1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76     842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44     924.86   75595.85
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Month']=df['Date'].apply(lambda z:z.month)
df['Day']=df['Date'].apply(lambda z:z.day)

# %%
df.drop(columns=['Date','Unnamed: 0'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  Month         18249 non-null  int64
#  13  Day           18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.shapedf.isnull().sum()
# Out:
# (18249, 14)

# %%
df.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# Month           0
# Day             0
# dtype: int64

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
sns.heatmap(df.corr(),vmax = 1, vmin = 0,annot = True)
plt.show()

# %%
#conventional avo. is more consumed
plt.pie(labels=['conventional','organic'],x=df.groupby('type')['Total Volume'].sum(),autopct='%1.0f%%',colors=['green','red'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f896d6a53d0>,
# ...
#  [Text(-1.0957170610706406, 0.09697485281617313, 'conventional'),
#   Text(1.0957170565309189, -0.09697490411039067, 'organic')],
#  [Text(-0.5976638514930765, 0.052895374263367156, '97%'),
#   Text(0.5976638490168648, -0.05289540224203127, '3%')])

# %%
#checking average price is more for conventional or organic
index = np.arange(2)
objects = ['organic','conventional']
plt.bar(index,[df[df.type == "organic"].AveragePrice.mean(), df[df.type == "conventional"].AveragePrice.mean()])
plt.xticks(index,objects)

plt.show()

# %%
#Average price for years
data = []
index=df.year.unique()

for i in df.year.unique():
    data.append(df[df.year == i].AveragePrice)
plt.boxplot(data)
plt.xticks([1,2,3,4],df.year.unique())
# Out:
# /home/fahad/.local/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ([<matplotlib.axis.XTick at 0x7f896f66c350>,
# ...
#  [Text(0, 0, '2015'),
#   Text(0, 0, '2016'),
#   Text(0, 0, '2017'),
#   Text(0, 0, '2018')])

# %%
#average price distribution for conventional and organic year wise
organic_year=[]
conv_year=[]
bw=.4
for i in df.year.unique():
    organic_year.append(df[(df.year==i) & (df.type=='organic')].AveragePrice.mean())
    conv_year.append(df[(df.year==i)&(df.type=='conventional')].AveragePrice.mean())

plt.bar(np.arange(df.year.nunique()),organic_year,bw, label = 'Organic')
plt.bar(np.arange(df.year.nunique())+bw,conv_year,bar_width, label = 'Conventional')    
plt.xticks(np.arange(df.year.nunique())+bw/2,df.year.unique())
plt.legend()
plt.show()

# %%
#month wise average price distribution for organic and conventional
def avfpriceof_conv_org_vs_year(y):
    org=[]
    conv=[]
    bw=.4
    for j in df.Month.unique():
        org.append(df[(df.year==y) & (df.Month==j) & (df.type=='organic')].AveragePrice.mean())
        conv.append(df[(df.year==y)& (df.Month==j) & (df.type=='conventional')].AveragePrice.mean())
    
    plt.bar(np.arange(df.Month.nunique()),org,bar_width, label = 'organic-'+str(y))
    plt.bar(np.arange(df.Month.nunique())+bw,conv,bar_width, label = 'conventional-' +str(y))    
    plt.xticks(np.arange(df.Month.nunique())+bw/2,df.Month.unique())
    plt.legend()
    plt.show()

    
    
years=df.year.unique()
for i in years:
    avfpriceof_conv_org_vs_year(i)

# %%
#Average price vs region  
regions=list(df.region.unique())
pr=[]
for i in df.region.unique():
    pr.append(df[df.region==i].AveragePrice.mean())
plt.figure(figsize=(24,10))
ax=sns.barplot(x=regions,y=pr)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel(' Price')
plt.title(' Prices of Avocado vs Region')
# Out:
# Text(0.5, 1.0, ' Prices of Avocado vs Region')

# %%
plt.figure(figsize=(12,5))
plt.title(" Price")
ax = sns.distplot(df["AveragePrice"], color = 'g')
